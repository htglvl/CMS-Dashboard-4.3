# %%
text = """substation_name
post_codes
voltage_of_connection_kv
maximum_requirement_mva
need_type
delivery_start_date
months_required
times_required
days_required
maximum_utilisation_price_mw
estimated_availability_hours
estimated_utilisation_hours
easting
northing
lat
long
period
geo_point_2d
site_number
ceiling_price_period"""

# %%
["incident_num", "incident_type", "outage_time",
"customers_affected", "customers_off_supply",
"incident_status", "estimated_restoration_time",
"latitude", "longitude"]

# %%
text.split("\n")
# Out:
# ['substation_name',
#  'post_codes',
#  'voltage_of_connection_kv',
#  'maximum_requirement_mva',
#  'need_type',
#  'delivery_start_date',
#  'months_required',
#  'times_required',
#  'days_required',
#  'maximum_utilisation_price_mw',
#  'estimated_availability_hours',
#  'estimated_utilisation_hours',
#  'easting',
#  'northing',
#  'lat',
#  'long',
#  'period',
#  'geo_point_2d',
#  'site_number',
#  'ceiling_price_period']

# %%
import pandas as pd
df = pd.read_csv("data/df_cleaned.csv")
df
# Out:
#        incident_duration  exceptional_event_id network_type  \
# 0                    185                   NaN           KV
# 1                      1                   NaN           HV
# 2                      1                   NaN           HV
# 3                     81                   NaN           HV
# 4                    230                   NaN           HV
# ...                  ...                   ...          ...
# 11311                 80                   NaN           LV
# 11312                235                   NaN           LV
# 11313                131                   NaN           HV
# 11314                  1                   NaN           HV
# 11315                  1                   NaN           HV
#
#        customer_affected      direct_cause_category  \
# 0                 1521.0  Generating Company or NGC
# 1                 1254.0    Unclassified or Unknown
# 2                15191.0    Unclassified or Unknown
# ...
